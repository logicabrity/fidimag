# %% [markdown]
# # Isolated skyrmion in confined helimagnetic nanostructure

# %% [markdown]
# **Authors**: Marijan Beg, Marc-Antonio Bisotti
#
# **Date**: 26 Feb 2016

# %% [markdown]
# ### Problem specification

# %% [markdown]
# A thin film disk sample with thickness $t=10 \,\text{nm}$ and diameter $d=150 \,\text{nm}$ is simulated. The material is FeGe with material parameters [1]:
#
# - exchange energy constant $A = 8.78 \times 10^{-12} \,\text{J/m}$,
# - magnetisation saturation $M_\text{s} = 3.84 \times 10^{5} \,\text{A/m}$, and
# - Dzyaloshinskii-Moriya energy constant $D = 1.58 \times 10^{-3} \,\text{J/m}^{2}$.
#
# It is expected that when the system is initialised in the uniform out-of-plane direction $\mathbf{m}_\text{init} = (0, 0, 1)$, it relaxes to the isolated Skyrmion (Sk) state (See Supplementary Information in Ref. 1).

# %% [markdown]
# ### Simulation

# %%
from fidimag.micro import Sim
from fidimag.common import CuboidMesh
from fidimag.micro import UniformExchange, Demag, DMI

# %% [markdown]
# The cuboidal thin film mesh which contains the disk is created:

# %%
# Mesh dimensions.
d = 150  # diameter (nm)
t = 10  # thickness (nm)

# Mesh discretisation.
dx = dy = dz = 2  # nm

mesh = CuboidMesh(nx=int(d/dx), ny=int(d/dy), nz=int(t/dz), dx=dx, dy=dy, dz=dz, unit_length=1e-9)

# %% [markdown]
# Since the disk geometry is simulated, it is required to set the saturation magnetisation to zero in the regions of the mesh outside the disk. In order to do that, the following function is created:

# %%
def Ms_function(Ms):
    def wrapped_function(pos):
        x, y, z = pos[0], pos[1], pos[2]
    
        r = ((x-d/2.)**2 + (y-d/2.)**2)**0.5  # distance from the centre
    
        if r <= d/2:
            # Mesh point is inside the disk.
            return Ms
        else:
            # Mesh point is outside the disk.
            return 0
    return wrapped_function

# %% [markdown]
# Having the magnetisation saturation function, the simulation object can be created:

# %%
# FeGe material paremeters.
Ms = 3.84e5  # saturation magnetisation (A/m)
A = 8.78e-12  # exchange energy constant (J/m)
D = 1.58e-3  # Dzyaloshinkii-Moriya energy constant (J/m**2)
alpha = 1  # Gilbert damping
gamma = 2.211e5  # gyromagnetic ration (m/As)

# Create simulation object.
sim = Sim(mesh)
sim.Ms = Ms_function(Ms)
sim.alpha = alpha
sim.gamma = gamma

# Add energies.
sim.add(UniformExchange(A=A))
sim.add(DMI(D=D))
sim.add(Demag())

# Since the magnetisation dynamics is not important in this stage,
# the precession term in LLG equation can be set to artificially zero.
sim.do_precession = False

# Initialise the system.
sim.set_m((0, 0, 1))

# %% [markdown]
# Now the system is relaxed:

# %%
# Relax the system to its equilibrium.
sim.relax(dt=1e-13, stopping_dmdt=0.01, max_steps=5000, save_m_steps=None, save_vtk_steps=None)
# Out:
# step=1, time=1e-13, max_dmdt=14319.7 ode_step=0
# step=2, time=2e-13, max_dmdt=13184.4 ode_step=1.33613e-14
# step=3, time=3e-13, max_dmdt=12226.2 ode_step=2.04423e-14
# step=4, time=4e-13, max_dmdt=11414.5 ode_step=2.04423e-14
# step=5, time=5e-13, max_dmdt=10721.8 ode_step=3.79691e-14
# step=6, time=6e-13, max_dmdt=10125.7 ode_step=3.79691e-14
# step=7, time=7e-13, max_dmdt=9608.01 ode_step=3.79691e-14
# step=8, time=8e-13, max_dmdt=9154.85 ode_step=6.5475e-14
# step=9, time=9e-13, max_dmdt=8755.18 ode_step=6.5475e-14
# step=10, time=1e-12, max_dmdt=8400.3 ode_step=4.74127e-14
# step=11, time=1.1e-12, max_dmdt=8083.25 ode_step=7.28784e-14
# step=12, time=1.2e-12, max_dmdt=7798.47 ode_step=7.28784e-14
# step=13, time=1.3e-12, max_dmdt=7541.41 ode_step=7.28784e-14
# step=14, time=1.4e-12, max_dmdt=7308.29 ode_step=7.28784e-14
# step=15, time=1.5e-12, max_dmdt=7095.96 ode_step=7.28784e-14
# step=16, time=1.6e-12, max_dmdt=6901.8 ode_step=7.28784e-14
# step=17, time=1.7e-12, max_dmdt=6723.6 ode_step=7.28784e-14
# step=18, time=1.8e-12, max_dmdt=6559.47 ode_step=7.28784e-14
# step=19, time=1.9e-12, max_dmdt=6407.8 ode_step=7.28784e-14
# step=20, time=2e-12, max_dmdt=6267.19 ode_step=7.28784e-14
# step=21, time=2.1e-12, max_dmdt=6136.45 ode_step=7.28784e-14
# step=22, time=2.2e-12, max_dmdt=6014.54 ode_step=7.28784e-14
# step=23, time=2.30934e-12, max_dmdt=5895.46 ode_step=1.09343e-13
# step=24, time=2.41869e-12, max_dmdt=5779.3 ode_step=1.09343e-13
# step=25, time=2.52803e-12, max_dmdt=5670.74 ode_step=1.09343e-13
# step=26, time=2.63737e-12, max_dmdt=5569 ode_step=1.09343e-13
# step=27, time=2.74672e-12, max_dmdt=5473.41 ode_step=1.09343e-13
# step=28, time=2.85606e-12, max_dmdt=5383.37 ode_step=1.09343e-13
# step=29, time=2.9654e-12, max_dmdt=5298.36 ode_step=1.09343e-13
# step=30, time=3.07474e-12, max_dmdt=5217.92 ode_step=1.09343e-13
# step=31, time=3.24137e-12, max_dmdt=5122.51 ode_step=1.66628e-13
# step=32, time=3.408e-12, max_dmdt=5014.87 ode_step=1.66628e-13
# step=33, time=3.57463e-12, max_dmdt=4914.82 ode_step=1.66628e-13
# step=34, time=3.74126e-12, max_dmdt=4821.46 ode_step=1.66628e-13
# step=35, time=3.90788e-12, max_dmdt=4734.02 ode_step=1.66628e-13
# step=36, time=4.07451e-12, max_dmdt=4651.85 ode_step=1.66628e-13
# step=37, time=4.24114e-12, max_dmdt=4574.38 ode_step=1.66628e-13
# step=38, time=4.40777e-12, max_dmdt=4501.14 ode_step=1.66628e-13
# step=39, time=4.5744e-12, max_dmdt=4431.69 ode_step=1.66628e-13
# step=40, time=4.74102e-12, max_dmdt=4365.68 ode_step=1.66628e-13
# step=41, time=4.90765e-12, max_dmdt=4302.78 ode_step=1.66628e-13
# step=42, time=5.07428e-12, max_dmdt=4242.7 ode_step=1.66628e-13
# step=43, time=5.33238e-12, max_dmdt=4169.95 ode_step=2.58101e-13
# step=44, time=5.59048e-12, max_dmdt=4086.33 ode_step=2.58101e-13
# step=45, time=5.84858e-12, max_dmdt=4007.49 ode_step=2.58101e-13
# step=46, time=6.10668e-12, max_dmdt=3936.81 ode_step=2.58101e-13
# step=47, time=6.36478e-12, max_dmdt=3887.05 ode_step=2.58101e-13
# step=48, time=6.62289e-12, max_dmdt=3839.03 ode_step=2.58101e-13
# step=49, time=6.88099e-12, max_dmdt=3792.54 ode_step=2.58101e-13
# step=50, time=7.13909e-12, max_dmdt=3747.4 ode_step=2.58101e-13
# step=51, time=7.39719e-12, max_dmdt=3703.44 ode_step=2.58101e-13
# step=52, time=7.65529e-12, max_dmdt=3660.53 ode_step=2.58101e-13
# step=53, time=7.91339e-12, max_dmdt=3618.52 ode_step=2.58101e-13
# step=54, time=8.17149e-12, max_dmdt=3577.29 ode_step=2.58101e-13
# step=55, time=8.42959e-12, max_dmdt=3536.73 ode_step=2.58101e-13
# step=56, time=8.68769e-12, max_dmdt=3496.75 ode_step=2.58101e-13
# step=57, time=9.07701e-12, max_dmdt=3447.3 ode_step=3.89321e-13
# step=58, time=9.46634e-12, max_dmdt=3388.59 ode_step=3.89321e-13
# step=59, time=9.85566e-12, max_dmdt=3349 ode_step=3.89321e-13
# step=60, time=1.0245e-11, max_dmdt=3314.77 ode_step=3.89321e-13
# step=61, time=1.06343e-11, max_dmdt=3279.49 ode_step=3.89321e-13
# step=62, time=1.10236e-11, max_dmdt=3243.14 ode_step=3.89321e-13
# step=63, time=1.14129e-11, max_dmdt=3205.67 ode_step=3.89321e-13
# step=64, time=1.18023e-11, max_dmdt=3167.07 ode_step=3.89321e-13
# step=65, time=1.21916e-11, max_dmdt=3127.32 ode_step=3.89321e-13
# step=66, time=1.25809e-11, max_dmdt=3086.41 ode_step=3.89321e-13
# step=67, time=1.29702e-11, max_dmdt=3059.68 ode_step=3.89321e-13
# step=68, time=1.33595e-11, max_dmdt=3036.68 ode_step=3.89321e-13
# step=69, time=1.37489e-11, max_dmdt=3011.71 ode_step=3.89321e-13
# step=70, time=1.41382e-11, max_dmdt=2984.82 ode_step=3.89321e-13
# step=71, time=1.45275e-11, max_dmdt=2956.05 ode_step=3.89321e-13
# step=72, time=1.49168e-11, max_dmdt=2926.59 ode_step=3.89321e-13
# step=73, time=1.53062e-11, max_dmdt=2943.57 ode_step=3.89321e-13
# step=74, time=1.56955e-11, max_dmdt=2958.63 ode_step=3.89321e-13
# step=75, time=1.62796e-11, max_dmdt=2974.69 ode_step=5.84142e-13
# step=76, time=1.68638e-11, max_dmdt=2990.12 ode_step=5.84142e-13
# step=77, time=1.74479e-11, max_dmdt=3001.25 ode_step=5.84142e-13
# step=78, time=1.8032e-11, max_dmdt=3008.12 ode_step=5.84142e-13
# step=79, time=1.86162e-11, max_dmdt=3010.79 ode_step=5.84142e-13
# step=80, time=1.92003e-11, max_dmdt=3009.37 ode_step=5.84142e-13
# step=81, time=1.97845e-11, max_dmdt=3003.95 ode_step=5.84142e-13
# step=82, time=2.03686e-11, max_dmdt=2994.67 ode_step=5.84142e-13
# step=83, time=2.09528e-11, max_dmdt=2981.69 ode_step=5.84142e-13
# step=84, time=2.15369e-11, max_dmdt=2965.16 ode_step=5.84142e-13
# step=85, time=2.2121e-11, max_dmdt=2945.28 ode_step=5.84142e-13
# step=86, time=2.27052e-11, max_dmdt=2922.22 ode_step=5.84142e-13
# step=87, time=2.32893e-11, max_dmdt=2896.19 ode_step=5.84142e-13
# step=88, time=2.38735e-11, max_dmdt=2867.4 ode_step=5.84142e-13
# step=89, time=2.44576e-11, max_dmdt=2836.05 ode_step=5.84142e-13
# step=90, time=2.50418e-11, max_dmdt=2802.35 ode_step=5.84142e-13
# step=91, time=2.56259e-11, max_dmdt=2771.18 ode_step=5.84142e-13
# step=92, time=2.621e-11, max_dmdt=2742.2 ode_step=5.84142e-13
# step=93, time=2.67942e-11, max_dmdt=2711.88 ode_step=5.84142e-13
# step=94, time=2.73783e-11, max_dmdt=2680.47 ode_step=5.84142e-13
# step=95, time=2.79625e-11, max_dmdt=2648.17 ode_step=5.84142e-13
# step=96, time=2.85466e-11, max_dmdt=2615.22 ode_step=5.84142e-13
# step=97, time=2.91307e-11, max_dmdt=2581.81 ode_step=5.84142e-13
# step=98, time=2.97149e-11, max_dmdt=2548.13 ode_step=5.84142e-13
# step=99, time=3.0299e-11, max_dmdt=2514.35 ode_step=5.84142e-13
# step=100, time=3.08832e-11, max_dmdt=2480.6 ode_step=5.84142e-13
# step=101, time=3.14673e-11, max_dmdt=2447.01 ode_step=5.84142e-13
# step=102, time=3.20515e-11, max_dmdt=2413.69 ode_step=5.84142e-13
# step=103, time=3.26356e-11, max_dmdt=2380.73 ode_step=5.84142e-13
# step=104, time=3.32197e-11, max_dmdt=2348.18 ode_step=5.84142e-13
# step=105, time=3.38039e-11, max_dmdt=2316.1 ode_step=5.84142e-13
# step=106, time=3.4388e-11, max_dmdt=2284.5 ode_step=5.84142e-13
# step=107, time=3.49722e-11, max_dmdt=2253.4 ode_step=5.84142e-13
# step=108, time=3.55563e-11, max_dmdt=2222.79 ode_step=5.84142e-13
# step=109, time=3.61405e-11, max_dmdt=2192.66 ode_step=5.84142e-13
# step=110, time=3.67246e-11, max_dmdt=2162.97 ode_step=5.84142e-13
# step=111, time=3.73087e-11, max_dmdt=2134.41 ode_step=5.84142e-13
# step=112, time=3.78929e-11, max_dmdt=2108.66 ode_step=5.84142e-13
# step=113, time=3.8477e-11, max_dmdt=2096.42 ode_step=5.84142e-13
# step=114, time=3.90612e-11, max_dmdt=2080.83 ode_step=5.84142e-13
# step=115, time=3.96453e-11, max_dmdt=2062.11 ode_step=5.84142e-13
# step=116, time=4.02295e-11, max_dmdt=2041.18 ode_step=5.84142e-13
# step=117, time=4.08136e-11, max_dmdt=2017.36 ode_step=5.84142e-13
# step=118, time=4.13977e-11, max_dmdt=1990.82 ode_step=5.84142e-13
# step=119, time=4.19819e-11, max_dmdt=1961.76 ode_step=5.84142e-13
# step=120, time=4.2566e-11, max_dmdt=1937.8 ode_step=5.84142e-13
# step=121, time=4.31502e-11, max_dmdt=1922.28 ode_step=5.84142e-13
# step=122, time=4.37343e-11, max_dmdt=1912.59 ode_step=5.84142e-13
# step=123, time=4.43185e-11, max_dmdt=1899.96 ode_step=5.84142e-13
# step=124, time=4.49026e-11, max_dmdt=1884.51 ode_step=5.84142e-13
# step=125, time=4.54867e-11, max_dmdt=1871.98 ode_step=5.84142e-13
# step=126, time=4.60709e-11, max_dmdt=1860.76 ode_step=5.84142e-13
# step=127, time=4.6655e-11, max_dmdt=1846.78 ode_step=5.84142e-13
# step=128, time=4.72392e-11, max_dmdt=1830.16 ode_step=5.84142e-13
# step=129, time=4.78233e-11, max_dmdt=1819.85 ode_step=5.84142e-13
# step=130, time=4.84074e-11, max_dmdt=1806.97 ode_step=5.84142e-13
# step=131, time=4.89916e-11, max_dmdt=1791.52 ode_step=5.84142e-13
# step=132, time=4.95757e-11, max_dmdt=1776.76 ode_step=5.84142e-13
# step=133, time=5.01599e-11, max_dmdt=1764.64 ode_step=5.84142e-13
# step=134, time=5.0744e-11, max_dmdt=1750.03 ode_step=5.84142e-13
# step=135, time=5.13282e-11, max_dmdt=1733.02 ode_step=5.84142e-13
# step=136, time=5.19123e-11, max_dmdt=1719.23 ode_step=5.84142e-13
# step=137, time=5.24964e-11, max_dmdt=1705.14 ode_step=5.84142e-13
# step=138, time=5.30806e-11, max_dmdt=1688.73 ode_step=5.84142e-13
# step=139, time=5.36647e-11, max_dmdt=1670.15 ode_step=5.84142e-13
# step=140, time=5.42489e-11, max_dmdt=1656.2 ode_step=5.84142e-13
# step=141, time=5.4833e-11, max_dmdt=1653.61 ode_step=5.84142e-13
# step=142, time=5.54172e-11, max_dmdt=1659.18 ode_step=5.84142e-13
# step=143, time=5.60013e-11, max_dmdt=1664.87 ode_step=5.84142e-13
# step=144, time=5.65854e-11, max_dmdt=1672.17 ode_step=5.84142e-13
# step=145, time=5.71696e-11, max_dmdt=1677.8 ode_step=5.84142e-13
# step=146, time=5.77537e-11, max_dmdt=1686.03 ode_step=5.84142e-13
# step=147, time=5.83379e-11, max_dmdt=1698.66 ode_step=5.84142e-13
# step=148, time=5.8922e-11, max_dmdt=1708.74 ode_step=5.84142e-13
# step=149, time=5.95062e-11, max_dmdt=1716.27 ode_step=5.84142e-13
# step=150, time=6.00903e-11, max_dmdt=1721.21 ode_step=5.84142e-13
# step=151, time=6.06744e-11, max_dmdt=1723.57 ode_step=5.84142e-13
# step=152, time=6.12586e-11, max_dmdt=1723.38 ode_step=5.84142e-13
# step=153, time=6.18427e-11, max_dmdt=1723.06 ode_step=5.84142e-13
# step=154, time=6.24269e-11, max_dmdt=1721.19 ode_step=5.84142e-13
# step=155, time=6.3011e-11, max_dmdt=1716.82 ode_step=5.84142e-13
# step=156, time=6.35951e-11, max_dmdt=1711.09 ode_step=5.84142e-13
# step=157, time=6.41793e-11, max_dmdt=1704.58 ode_step=5.84142e-13
# step=158, time=6.511e-11, max_dmdt=1692.48 ode_step=9.30704e-13
# step=159, time=6.60407e-11, max_dmdt=1675.17 ode_step=9.30704e-13
# step=160, time=6.69714e-11, max_dmdt=1654.93 ode_step=9.30704e-13
# step=161, time=6.79021e-11, max_dmdt=1629.39 ode_step=9.30704e-13
# step=162, time=6.88328e-11, max_dmdt=1598.98 ode_step=9.30704e-13
# step=163, time=6.97635e-11, max_dmdt=1564.18 ode_step=9.30704e-13
# step=164, time=7.06942e-11, max_dmdt=1525.5 ode_step=9.30704e-13
# step=165, time=7.16249e-11, max_dmdt=1483.48 ode_step=9.30704e-13
# step=166, time=7.25556e-11, max_dmdt=1438.63 ode_step=9.30704e-13
# step=167, time=7.34863e-11, max_dmdt=1392.37 ode_step=9.30704e-13
# step=168, time=7.4417e-11, max_dmdt=1344.24 ode_step=9.30704e-13
# step=169, time=7.53477e-11, max_dmdt=1294.7 ode_step=9.30704e-13
# step=170, time=7.62784e-11, max_dmdt=1244.22 ode_step=9.30704e-13
# step=171, time=7.72092e-11, max_dmdt=1193.23 ode_step=9.30704e-13
# step=172, time=7.81399e-11, max_dmdt=1142.1 ode_step=9.30704e-13
# step=173, time=7.90706e-11, max_dmdt=1091.2 ode_step=9.30704e-13
# step=174, time=8.00013e-11, max_dmdt=1040.83 ode_step=9.30704e-13
# step=175, time=8.0932e-11, max_dmdt=991.261 ode_step=9.30704e-13
# step=176, time=8.18627e-11, max_dmdt=942.721 ode_step=9.30704e-13
# step=177, time=8.27934e-11, max_dmdt=912.717 ode_step=9.30704e-13
# step=178, time=8.37241e-11, max_dmdt=885.588 ode_step=9.30704e-13
# step=179, time=8.46548e-11, max_dmdt=857.751 ode_step=9.30704e-13
# step=180, time=8.55855e-11, max_dmdt=829.667 ode_step=9.30704e-13
# step=181, time=8.65162e-11, max_dmdt=801.808 ode_step=9.30704e-13
# step=182, time=8.74469e-11, max_dmdt=773.693 ode_step=9.30704e-13
# step=183, time=8.83776e-11, max_dmdt=745.812 ode_step=9.30704e-13
# step=184, time=8.93083e-11, max_dmdt=718.199 ode_step=9.30704e-13
# step=185, time=9.0239e-11, max_dmdt=690.691 ode_step=9.30704e-13
# step=186, time=9.11697e-11, max_dmdt=663.41 ode_step=9.30704e-13
# step=187, time=9.21004e-11, max_dmdt=636.696 ode_step=9.30704e-13
# step=188, time=9.30311e-11, max_dmdt=610.416 ode_step=9.30704e-13
# step=189, time=9.39618e-11, max_dmdt=584.606 ode_step=9.30704e-13
# step=190, time=9.48925e-11, max_dmdt=559.336 ode_step=9.30704e-13
# step=191, time=9.58232e-11, max_dmdt=534.773 ode_step=9.30704e-13
# step=192, time=9.67539e-11, max_dmdt=510.854 ode_step=9.30704e-13
# step=193, time=9.76846e-11, max_dmdt=487.605 ode_step=9.30704e-13
# step=194, time=9.86153e-11, max_dmdt=465.06 ode_step=9.30704e-13
# step=195, time=9.95461e-11, max_dmdt=443.257 ode_step=9.30704e-13
# step=196, time=1.01049e-10, max_dmdt=415.951 ode_step=1.50272e-12
# step=197, time=1.02552e-10, max_dmdt=383.937 ode_step=1.50272e-12
# step=198, time=1.04054e-10, max_dmdt=353.887 ode_step=1.50272e-12
# step=199, time=1.05557e-10, max_dmdt=325.782 ode_step=1.50272e-12
# step=200, time=1.0706e-10, max_dmdt=299.58 ode_step=1.50272e-12
# step=201, time=1.08562e-10, max_dmdt=275.222 ode_step=1.50272e-12
# step=202, time=1.10065e-10, max_dmdt=252.633 ode_step=1.50272e-12
# step=203, time=1.11568e-10, max_dmdt=231.731 ode_step=1.50272e-12
# step=204, time=1.13071e-10, max_dmdt=212.426 ode_step=1.50272e-12
# step=205, time=1.14573e-10, max_dmdt=194.628 ode_step=1.50272e-12
# step=206, time=1.16076e-10, max_dmdt=178.243 ode_step=1.50272e-12
# step=207, time=1.17579e-10, max_dmdt=163.18 ode_step=1.50272e-12
# step=208, time=1.19081e-10, max_dmdt=149.348 ode_step=1.50272e-12
# step=209, time=1.20584e-10, max_dmdt=136.66 ode_step=1.50272e-12
# step=210, time=1.22087e-10, max_dmdt=125.032 ode_step=1.50272e-12
# step=211, time=1.2359e-10, max_dmdt=114.385 ode_step=1.50272e-12
# step=212, time=1.25092e-10, max_dmdt=104.642 ode_step=1.50272e-12
# step=213, time=1.26595e-10, max_dmdt=95.7317 ode_step=1.50272e-12
# step=214, time=1.28858e-10, max_dmdt=85.6961 ode_step=2.26325e-12
# step=215, time=1.31122e-10, max_dmdt=75.1027 ode_step=2.26325e-12
# step=216, time=1.33385e-10, max_dmdt=65.8597 ode_step=2.26325e-12
# step=217, time=1.35648e-10, max_dmdt=57.7993 ode_step=2.26325e-12
# step=218, time=1.37911e-10, max_dmdt=50.7725 ode_step=2.26325e-12
# step=219, time=1.40175e-10, max_dmdt=44.6477 ode_step=2.26325e-12
# step=220, time=1.42438e-10, max_dmdt=39.3088 ode_step=2.26325e-12
# step=221, time=1.44701e-10, max_dmdt=34.6548 ode_step=2.26325e-12
# step=222, time=1.46964e-10, max_dmdt=30.8043 ode_step=2.26325e-12
# step=223, time=1.49228e-10, max_dmdt=28.328 ode_step=2.26325e-12
# step=224, time=1.51491e-10, max_dmdt=26.0756 ode_step=2.26325e-12
# step=225, time=1.53754e-10, max_dmdt=24.0257 ode_step=2.26325e-12
# step=226, time=1.56017e-10, max_dmdt=22.1592 ode_step=2.26325e-12
# step=227, time=1.58281e-10, max_dmdt=20.459 ode_step=2.26325e-12
# step=228, time=1.60544e-10, max_dmdt=18.9096 ode_step=2.26325e-12
# step=229, time=1.62807e-10, max_dmdt=17.497 ode_step=2.26325e-12
# step=230, time=1.6507e-10, max_dmdt=16.2086 ode_step=2.26325e-12
# step=231, time=1.67334e-10, max_dmdt=15.033 ode_step=2.26325e-12
# step=232, time=1.69597e-10, max_dmdt=13.9599 ode_step=2.26325e-12
# step=233, time=1.7186e-10, max_dmdt=12.9798 ode_step=2.26325e-12
# step=234, time=1.74123e-10, max_dmdt=12.0845 ode_step=2.26325e-12
# step=235, time=1.76387e-10, max_dmdt=11.2663 ode_step=2.26325e-12
# step=236, time=1.7865e-10, max_dmdt=10.5182 ode_step=2.26325e-12
# step=237, time=1.80913e-10, max_dmdt=9.83384 ode_step=2.26325e-12
# step=238, time=1.84531e-10, max_dmdt=9.03402 ode_step=3.61758e-12
# step=239, time=1.88148e-10, max_dmdt=8.16374 ode_step=3.61758e-12
# step=240, time=1.91766e-10, max_dmdt=7.40713 ode_step=3.61758e-12
# step=241, time=1.95383e-10, max_dmdt=6.74851 ode_step=3.61758e-12
# step=242, time=1.99001e-10, max_dmdt=6.17441 ode_step=3.61758e-12
# step=243, time=2.02619e-10, max_dmdt=5.67329 ode_step=3.61758e-12
# step=244, time=2.06236e-10, max_dmdt=5.23545 ode_step=3.61758e-12
# step=245, time=2.09854e-10, max_dmdt=4.85923 ode_step=3.61758e-12
# step=246, time=2.13471e-10, max_dmdt=4.52941 ode_step=3.61758e-12
# step=247, time=2.17089e-10, max_dmdt=4.23969 ode_step=3.61758e-12
# step=248, time=2.20706e-10, max_dmdt=3.98468 ode_step=3.61758e-12
# step=249, time=2.24324e-10, max_dmdt=3.75978 ode_step=3.61758e-12
# step=250, time=2.27942e-10, max_dmdt=3.56097 ode_step=3.61758e-12
# step=251, time=2.31559e-10, max_dmdt=3.3848 ode_step=3.61758e-12
# step=252, time=2.35177e-10, max_dmdt=3.22834 ode_step=3.61758e-12
# step=253, time=2.38794e-10, max_dmdt=3.08904 ode_step=3.61758e-12
# step=254, time=2.42412e-10, max_dmdt=2.96464 ode_step=3.61758e-12
# step=255, time=2.4603e-10, max_dmdt=2.85323 ode_step=3.61758e-12
# step=256, time=2.51879e-10, max_dmdt=2.72498 ode_step=5.84984e-12
# step=257, time=2.57729e-10, max_dmdt=2.58799 ode_step=5.84984e-12
# step=258, time=2.63579e-10, max_dmdt=2.47138 ode_step=5.84984e-12
# step=259, time=2.69429e-10, max_dmdt=2.37133 ode_step=5.84984e-12
# step=260, time=2.75279e-10, max_dmdt=2.2848 ode_step=5.84984e-12
# step=261, time=2.81129e-10, max_dmdt=2.20942 ode_step=5.84984e-12
# step=262, time=2.86978e-10, max_dmdt=2.16482 ode_step=5.84984e-12
# step=263, time=2.92828e-10, max_dmdt=2.12429 ode_step=5.84984e-12
# step=264, time=2.98678e-10, max_dmdt=2.08627 ode_step=5.84984e-12
# step=265, time=3.04528e-10, max_dmdt=2.05062 ode_step=5.84984e-12
# step=266, time=3.10378e-10, max_dmdt=2.01851 ode_step=5.84984e-12
# step=267, time=3.16228e-10, max_dmdt=1.99408 ode_step=5.84984e-12
# step=268, time=3.22077e-10, max_dmdt=1.97114 ode_step=5.84984e-12
# step=269, time=3.27927e-10, max_dmdt=1.9496 ode_step=5.84984e-12
# step=270, time=3.33777e-10, max_dmdt=1.92937 ode_step=5.84984e-12
# step=271, time=3.39627e-10, max_dmdt=1.91036 ode_step=5.84984e-12
# step=272, time=3.45477e-10, max_dmdt=1.8925 ode_step=5.84984e-12
# step=273, time=3.51327e-10, max_dmdt=1.87944 ode_step=5.84984e-12
# step=274, time=3.57176e-10, max_dmdt=1.86888 ode_step=5.84984e-12
# step=275, time=3.63026e-10, max_dmdt=1.85893 ode_step=5.84984e-12
# step=276, time=3.68876e-10, max_dmdt=1.84953 ode_step=5.84984e-12
# step=277, time=3.77656e-10, max_dmdt=1.83855 ode_step=8.78e-12
# step=278, time=3.86436e-10, max_dmdt=1.82633 ode_step=8.78e-12
# step=279, time=3.95216e-10, max_dmdt=1.81577 ode_step=8.78e-12
# step=280, time=4.03996e-10, max_dmdt=1.81068 ode_step=8.78e-12
# step=281, time=4.18759e-10, max_dmdt=1.80436 ode_step=1.47634e-11
# step=282, time=4.33523e-10, max_dmdt=1.79707 ode_step=1.47634e-11
# step=283, time=4.48286e-10, max_dmdt=1.79043 ode_step=1.47634e-11
# step=284, time=4.6305e-10, max_dmdt=1.78434 ode_step=1.47634e-11
# step=285, time=4.77813e-10, max_dmdt=1.77871 ode_step=1.47634e-11
# step=286, time=4.92576e-10, max_dmdt=1.77669 ode_step=1.47634e-11
# step=287, time=5.0734e-10, max_dmdt=1.77474 ode_step=1.47634e-11
# step=288, time=5.22103e-10, max_dmdt=1.7726 ode_step=1.47634e-11
# step=289, time=5.36867e-10, max_dmdt=1.77031 ode_step=1.47634e-11
# step=290, time=5.5163e-10, max_dmdt=1.76787 ode_step=1.47634e-11
# step=291, time=5.66393e-10, max_dmdt=1.76533 ode_step=1.47634e-11
# step=292, time=5.81157e-10, max_dmdt=1.7627 ode_step=1.47634e-11
# step=293, time=6.03944e-10, max_dmdt=1.75923 ode_step=2.27874e-11
# step=294, time=6.26731e-10, max_dmdt=1.75489 ode_step=2.27874e-11
# step=295, time=6.49519e-10, max_dmdt=1.75044 ode_step=2.27874e-11
# step=296, time=6.72306e-10, max_dmdt=1.74589 ode_step=2.27874e-11
# step=297, time=6.95094e-10, max_dmdt=1.74129 ode_step=2.27874e-11
# step=298, time=7.17881e-10, max_dmdt=1.73663 ode_step=2.27874e-11
# step=299, time=7.40668e-10, max_dmdt=1.73194 ode_step=2.27874e-11
# step=300, time=7.63456e-10, max_dmdt=1.72722 ode_step=2.27874e-11
# step=301, time=7.86243e-10, max_dmdt=1.72248 ode_step=2.27874e-11
# step=302, time=8.09031e-10, max_dmdt=1.71773 ode_step=2.27874e-11
# step=303, time=8.31818e-10, max_dmdt=1.71297 ode_step=2.27874e-11
# step=304, time=8.67753e-10, max_dmdt=1.70683 ode_step=3.59347e-11
# step=305, time=9.03687e-10, max_dmdt=1.69931 ode_step=3.59347e-11
# step=306, time=9.39622e-10, max_dmdt=1.6918 ode_step=3.59347e-11
# step=307, time=9.75557e-10, max_dmdt=1.6843 ode_step=3.59347e-11
# step=308, time=1.01149e-09, max_dmdt=1.67681 ode_step=3.59347e-11
# step=309, time=1.04743e-09, max_dmdt=1.66934 ode_step=3.59347e-11
# step=310, time=1.10815e-09, max_dmdt=1.65931 ode_step=6.07275e-11
# step=311, time=1.16888e-09, max_dmdt=1.64676 ode_step=6.07275e-11
# step=312, time=1.22961e-09, max_dmdt=1.63426 ode_step=6.07275e-11
# step=313, time=1.29034e-09, max_dmdt=1.62182 ode_step=6.07275e-11
# step=314, time=1.39035e-09, max_dmdt=1.60544 ode_step=1.0001e-10
# step=315, time=1.49036e-09, max_dmdt=1.58521 ode_step=1.0001e-10
# step=316, time=1.59037e-09, max_dmdt=1.56514 ode_step=1.0001e-10
# step=317, time=1.69038e-09, max_dmdt=1.54523 ode_step=1.0001e-10
# step=318, time=1.85515e-09, max_dmdt=1.51916 ode_step=1.64769e-10
# step=319, time=2.01991e-09, max_dmdt=1.48712 ode_step=1.64769e-10
# step=320, time=2.18468e-09, max_dmdt=1.45556 ode_step=1.64769e-10
# step=321, time=2.34945e-09, max_dmdt=1.42449 ode_step=1.64769e-10
# step=322, time=2.61545e-09, max_dmdt=1.38465 ode_step=2.65997e-10
# step=323, time=2.88145e-09, max_dmdt=1.3366 ode_step=2.65997e-10
# step=324, time=3.14744e-09, max_dmdt=1.28987 ode_step=2.65997e-10
# step=325, time=3.41344e-09, max_dmdt=1.24447 ode_step=2.65997e-10
# step=326, time=3.67944e-09, max_dmdt=1.20041 ode_step=2.65997e-10
# step=327, time=3.94544e-09, max_dmdt=1.15767 ode_step=2.65997e-10
# step=328, time=4.21143e-09, max_dmdt=1.11625 ode_step=2.65997e-10
# step=329, time=4.47743e-09, max_dmdt=1.07613 ode_step=2.65997e-10
# step=330, time=4.74343e-09, max_dmdt=1.0373 ode_step=2.65997e-10
# step=331, time=5.00942e-09, max_dmdt=0.999731 ode_step=2.65997e-10
# step=332, time=5.27542e-09, max_dmdt=0.963407 ode_step=2.65997e-10
# step=333, time=5.70887e-09, max_dmdt=0.917577 ode_step=4.3345e-10
# step=334, time=6.14232e-09, max_dmdt=0.863498 ode_step=4.3345e-10
# step=335, time=6.57577e-09, max_dmdt=0.812433 ode_step=4.3345e-10
# step=336, time=7.00922e-09, max_dmdt=0.764251 ode_step=4.3345e-10
# step=337, time=7.44267e-09, max_dmdt=0.71882 ode_step=4.3345e-10
# step=338, time=7.87612e-09, max_dmdt=0.676007 ode_step=4.3345e-10
# step=339, time=8.30957e-09, max_dmdt=0.635681 ode_step=4.3345e-10
# step=340, time=8.74302e-09, max_dmdt=0.597713 ode_step=4.3345e-10
# step=341, time=9.41663e-09, max_dmdt=0.552581 ode_step=6.73611e-10
# step=342, time=1.00902e-08, max_dmdt=0.502047 ode_step=6.73611e-10
# step=343, time=1.07639e-08, max_dmdt=0.456102 ode_step=6.73611e-10
# step=344, time=1.14375e-08, max_dmdt=0.414346 ode_step=6.73611e-10
# step=345, time=1.21111e-08, max_dmdt=0.376409 ode_step=6.73611e-10
# step=346, time=1.27847e-08, max_dmdt=0.341948 ode_step=6.73611e-10
# step=347, time=1.34583e-08, max_dmdt=0.310648 ode_step=6.73611e-10
# step=348, time=1.41319e-08, max_dmdt=0.282221 ode_step=6.73611e-10
# step=349, time=1.48055e-08, max_dmdt=0.256404 ode_step=6.73611e-10
# step=350, time=1.54791e-08, max_dmdt=0.232958 ode_step=6.73611e-10
# step=351, time=1.61527e-08, max_dmdt=0.211665 ode_step=6.73611e-10
# step=352, time=1.68264e-08, max_dmdt=0.192327 ode_step=6.73611e-10
# step=353, time=1.75e-08, max_dmdt=0.174763 ode_step=6.73611e-10
# step=354, time=1.81736e-08, max_dmdt=0.15881 ode_step=6.73611e-10
# step=355, time=1.88472e-08, max_dmdt=0.144319 ode_step=6.73611e-10
# step=356, time=1.95208e-08, max_dmdt=0.131155 ode_step=6.73611e-10
# step=357, time=2.01944e-08, max_dmdt=0.119197 ode_step=6.73611e-10
# step=358, time=2.0868e-08, max_dmdt=0.108333 ode_step=6.73611e-10
# step=359, time=2.15416e-08, max_dmdt=0.0984623 ode_step=6.73611e-10
# step=360, time=2.22152e-08, max_dmdt=0.089494 ode_step=6.73611e-10
# step=361, time=2.28889e-08, max_dmdt=0.0813449 ode_step=6.73611e-10
# step=362, time=2.35625e-08, max_dmdt=0.0739401 ode_step=6.73611e-10
# step=363, time=2.45943e-08, max_dmdt=0.0655604 ode_step=1.03184e-09
# step=364, time=2.56261e-08, max_dmdt=0.0566475 ode_step=1.03184e-09
# step=365, time=2.6658e-08, max_dmdt=0.0489492 ode_step=1.03184e-09
# step=366, time=2.76898e-08, max_dmdt=0.0422997 ode_step=1.03184e-09
# step=367, time=2.87216e-08, max_dmdt=0.0365549 ode_step=1.03184e-09
# step=368, time=2.97535e-08, max_dmdt=0.0315911 ode_step=1.03184e-09
# step=369, time=3.07853e-08, max_dmdt=0.0273019 ode_step=1.03184e-09
# step=370, time=3.18172e-08, max_dmdt=0.0235957 ode_step=1.03184e-09
# step=371, time=3.2849e-08, max_dmdt=0.0203932 ode_step=1.03184e-09
# step=372, time=3.38808e-08, max_dmdt=0.0176258 ode_step=1.03184e-09
# step=373, time=3.49127e-08, max_dmdt=0.0152341 ode_step=1.03184e-09
# step=374, time=3.59445e-08, max_dmdt=0.0131671 ode_step=1.03184e-09
# step=375, time=3.69763e-08, max_dmdt=0.0113806 ode_step=1.03184e-09
# step=376, time=3.80082e-08, max_dmdt=0.0098368 ode_step=1.03184e-09

# %% [markdown]
# The magnetisation components of obtained equilibrium configuration can be plotted in the following way:

# %%
# PYTEST_VALIDATE_IGNORE_OUTPUT
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_magnetisation(m, layer=0):
    n_layer = int(d/dx) * int(d/dy)
    m.shape = (-1, 3)
    
    mx = m[:, 0][layer*n_layer:(layer+1)*n_layer]
    my = m[:, 1][layer*n_layer:(layer+1)*n_layer]
    mz = m[:, 2][layer*n_layer:(layer+1)*n_layer]
    mx.shape = (int(d/dx), int(d/dy))
    my.shape = (int(d/dx), int(d/dy))
    mz.shape = (int(d/dx), int(d/dy))
    
    extent = [0, d, 0, d]
    plt.figure(figsize=(20, 10))
    plt.subplot(1, 3, 1)
    plt.imshow(mx, extent=extent)
    plt.title('mx')
    plt.xlabel('x (nm)')
    plt.ylabel('y (nm)')
    plt.subplot(1, 3, 2)
    plt.imshow(my, extent=extent)
    plt.xlabel('x (nm)')
    plt.ylabel('y (nm)')
    plt.title('my')
    plt.subplot(1, 3, 3)
    plt.imshow(mz, extent=extent)
    plt.xlabel('x (nm)')
    plt.ylabel('y (nm)')
    plt.title('mz')
    
plot_magnetisation(sim.spin, layer=0)

# %% [markdown]
# ### References
#
# [1] Beg, M. et al. Ground state search, hysteretic behaviour, and reversal mechanism of skyrmionic textures in confined helimagnetic nanostructures. *Sci. Rep.* **5**, 17137 (2015).
